# %%
import numpy as nm
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
Y = dataset.iloc[:,-1].values

# %% [markdown]
# # Linear Regression Prediction

# %%
from sklearn.linear_model import LinearRegression
lin_reg_1 = LinearRegression()
lin_reg_1.fit(X,Y)
# Out:
# LinearRegression()

# %%
lin_reg_1.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
plt.scatter(X,Y,color = "red")
plt.plot(X, lin_reg_1.predict(X),color = "blue")
plt.title("linear regression prediction")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # Polynomial Regression Prediction

# %%
from sklearn.preprocessing import PolynomialFeatures
X_poly = PolynomialFeatures(degree = 4)
X_features = X_poly.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_features,Y)
# Out:
# LinearRegression()

# %%
poly_reg.predict(X_poly.fit_transform([[6.5]]))
# Out:
# array([158862.4526515])

# %%
plt.scatter(X,Y, color = "red")
plt.plot(X, poly_reg.predict(X_features), color = "Blue")
plt.title("Polynomial regression results")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()
